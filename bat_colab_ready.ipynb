# %% [markdown]
# # Bat_Indian_Model — Colab quickstart
#
# This notebook shows the minimal steps to run the project on Google Colab: clone the repository, install dependencies, and run a quick smoke training run on the included sample data.

# %%
# 1) Clone the repo and change into it
# !git clone https://github.com/Quarkisinproton/Bat_Indian_Model.git
# %cd Bat_Indian_Model
# !ls -la
# Out:
# Cloning into 'Bat_Indian_Model'...
# remote: Enumerating objects: 173, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 173 (delta 3), reused 29 (delta 2), pack-reused 139 (from 1)
# Receiving objects: 100% (173/173), 133.26 MiB | 15.77 MiB/s, done.
# Resolving deltas: 100% (25/25), done.
# Updating files: 100% (90/90), done.
# /content/Bat_Indian_Model
# total 124
# drwxr-xr-x 7 root root 4096 Nov 23 06:30 .
# drwxr-xr-x 1 root root 4096 Nov 23 06:30 ..
# -rw-r--r-- 1 root root 8279 Nov 23 06:30 ARCHITECTURE.md
# -rw-r--r-- 1 root root 2613 Nov 23 06:30 bat_colab_ready.ipynb
# drwxr-xr-x 2 root root 4096 Nov 23 06:30 config
# drwxr-xr-x 5 root root 4096 Nov 23 06:30 data
# -rw-r--r-- 1 root root 7151 Nov 23 06:30 evaluate.py
# -rw-r--r-- 1 root root 5980 Nov 23 06:30 example_usage.py
# drwxr-xr-x 8 root root 4096 Nov 23 06:30 .git
# -rw-r--r-- 1 root root  447 Nov 23 06:30 .gitignore
# ...

# %%
# 2) Install Python dependencies (may take a few minutes)
# You can customize this to a specific TF wheel if needed for GPU support
# !pip install -r requirements.txt -q

# %% [markdown]
# ## Quick import & install notes
# After cloning and installing dependencies, either install the repo or add it to Python path so you can import modules directly.
#
# In a Colab code cell run (bash):
# ```bash
# !pip install -r requirements.txt -q
# !pip install -e .
# ```
# Then in Python (Colab) run:
# ```python
# import sys
# sys.path.insert(0, '/content/Bat_Indian_Model')  # only needed if you didn't pip install -e .
# from src.models.bat_classifier import BatSpeciesClassifier
# ```
# If you prefer not to install, adding the repository root to sys.path (as shown) is sufficient for imports.

# %%
# !pip install -r requirements.txt -q
# !pip install -e .
# Out:
# Obtaining file:///content/Bat_Indian_Model
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for bat-species-classifier
# ...

# %%
# 3) (Optional) Mount Google Drive if your dataset is stored there
from google.colab import drive
# drive.mount('/content/drive')
# If you mount, update --data_dir to point to your mounted folder

# %%
# 4) Run a quick smoke training run on the bundled sample data
# Reduce epochs/batch size for a fast smoke test
# !python train.py --data_dir data/sample --epochs 1 --batch_size 4
